# %% [markdown]
# # รหัสนักศึกษา-ชื่อ-นามสกุล (Heading)
# # 620710167-Panuwat-Wichitsiriwat

# %% [markdown]
# ### ในการทำแบบฝึกหัดให้เพิ่ม cell ด้านล่างของโจทย์เพื่อเขียน code

# %% [markdown]
# import Library ที่สำคัญในงาน

# %%
#Import Python Libraries
import numpy as np
# import scipy as sp
import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns

# %% [markdown]
# 1. Read csv file ("Pokemon.csv")

# %%
#Read csv file
df = pd.read_csv("Pokemon.csv")

# %% [markdown]
# 2. เรียกดูข้อมูล 15 แถวสุดท้ายและคำนวณค่าสถิติพื้นฐาน

# %%
df.tail(15).mean()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12368\67590148.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.tail(15).mean()
# #             715.800000
# Total         548.000000
# HP             79.333333
# Attack        104.533333
# Defense       104.066667
# Sp. Atk        96.333333
# Sp. Def        88.466667
# Speed          75.266667
# Generation      6.000000
# Legendary       0.533333
# dtype: float64

# %% [markdown]
# 3. เลือกข้อมูลตั้งแต่แถวที่ 25-50 แบ่งกลุ่มตามธาตุหลัก (Type 1)และรอง (Type 2)เพื่อแสดงค่าพลังรวมเฉลี่ยของโปเกม่อน

# %%
df.loc[25:50]
# Out:
#      #        Name    Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 25  20    Raticate    Normal     NaN    413   55      81       60       50
# 26  21     Spearow    Normal  Flying    262   40      60       30       31
# 27  22      Fearow    Normal  Flying    442   65      90       65       61
# 28  23       Ekans    Poison     NaN    288   35      60       44       40
# 29  24       Arbok    Poison     NaN    438   60      85       69       65
# 30  25     Pikachu  Electric     NaN    320   35      55       40       50
# 31  26      Raichu  Electric     NaN    485   60      90       55       90
# 32  27   Sandshrew    Ground     NaN    300   50      75       85       20
# 33  28   Sandslash    Ground     NaN    450   75     100      110       45
# 34  29    Nidoran♀    Poison     NaN    275   55      47       52       40
# 35  30    Nidorina    Poison     NaN    365   70      62       67       55
# ...

# %%
4. แสดงโปเกม่อนธาตุระดับตำนาน Legendary ธาตุมังกร (Dragon) 
ที่มีค่าพลังรวมมากกว่า 500 และมีค่า Sp. Atk,Sp. Def มากกว่า 50 ในแถวที่ 400-500

# %%
# Out:
#        #                   Name  Type 1   Type 2  Total   HP  Attack  Defense  \
# 417  380                 Latias  Dragon  Psychic    600   80      80       90
# 418  380      LatiasMega Latias  Dragon  Psychic    700   80     100      120
# 419  381                 Latios  Dragon  Psychic    600   80      90       80
# 420  381      LatiosMega Latios  Dragon  Psychic    700   80     130      100
# 425  384               Rayquaza  Dragon   Flying    680  105     150       90
# 426  384  RayquazaMega Rayquaza  Dragon   Flying    780  105     180      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 417      110      130    110           3       True
# 418      140      150    110           3       True
# 419      130      110    110           3       True
# 420      160      120    110           3       True
# 425      150       90     95           3       True
# 426      180      100    115           3       True
